# %%
#!pip install Pyppeteer
#!pip install pillow_heif

# %%
from PIL import Image
from pillow_heif import register_heif_opener
import json
import os
import ast

# %%
def get_exif(filename):
    image = Image.open(filename)
    image.verify()
    return image.getexif().get_ifd(0x8825)

# %%
def get_geotagging(exif):
    geo_tagging_info = {}
    if not exif:
        raise ValueError("No EXIF metadata found")
    else:
        gps_keys = ['GPSVersionID', 'GPSLatitudeRef', 'GPSLatitude', 'GPSLongitudeRef', 'GPSLongitude',
                    'GPSAltitudeRef', 'GPSAltitude', 'GPSTimeStamp', 'GPSSatellites', 'GPSStatus', 'GPSMeasureMode',
                    'GPSDOP', 'GPSSpeedRef', 'GPSSpeed', 'GPSTrackRef', 'GPSTrack', 'GPSImgDirectionRef',
                    'GPSImgDirection', 'GPSMapDatum', 'GPSDestLatitudeRef', 'GPSDestLatitude', 'GPSDestLongitudeRef',
                    'GPSDestLongitude', 'GPSDestBearingRef', 'GPSDestBearing', 'GPSDestDistanceRef', 'GPSDestDistance',
                    'GPSProcessingMethod', 'GPSAreaInformation', 'GPSDateStamp', 'GPSDifferential']

        for k, v in exif.items():
            try:
                geo_tagging_info[gps_keys[k]] = str(v)
            except IndexError:
                pass
        return geo_tagging_info

# %%
def dms_to_decimal(degrees, minutes, seconds):
    return degrees + minutes / 60 + seconds / 3600

# %%
def parse_coordinates(coord_str):
    return tuple(map(float, ast.literal_eval(coord_str)))

# %%
register_heif_opener()

# %%
#Get current files from directory
directory_path = "/Users/WDescamps/Downloads/images_dune"
trees_data_list = []

if os.path.exists(directory_path) and os.path.isdir(directory_path):
    filenames = os.listdir(directory_path)
    
    print("List of filenames in the directory:")
    for filename in filenames :
        if not filename.startswith('.'):
            #print(filename)
            image_info = get_exif(directory_path+"/"+filename)
            results = get_geotagging(image_info)
            #print(results)

            GPSLatitude = parse_coordinates(results['GPSLatitude'])
            GPSLongitude = parse_coordinates(results['GPSLongitude'])
            GPSAltitude = float(results['GPSAltitude'])

            extracted_data = {
                'GPSLatitude': GPSLatitude,
                'GPSLongitude': GPSLongitude,
                'GPSAltitude': GPSAltitude,
                'name': filename
            }

        print(extracted_data)
        trees_data_list.append(extracted_data)
        
else:
    print("The provided path is not a valid directory.")
# Out:
# List of filenames in the directory:
# {'GPSLatitude': (43.0, 48.0, 52.65), 'GPSLongitude': (1.0, 23.0, 1.42), 'GPSAltitude': 26.483714483714483, 'name': 'IMG_2851.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.75), 'GPSLongitude': (1.0, 23.0, 0.53), 'GPSAltitude': 28.867976171308968, 'name': 'IMG_2943.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 52.64), 'GPSLongitude': (1.0, 23.0, 1.04), 'GPSAltitude': 15.515895883186014, 'name': 'IMG_2847.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.28), 'GPSLongitude': (1.0, 23.0, 0.24), 'GPSAltitude': 24.90541162042005, 'name': 'IMG_2867.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.56), 'GPSLongitude': (1.0, 23.0, 0.17), 'GPSAltitude': 27.0630409929773, 'name': 'IMG_2871.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.56), 'GPSLongitude': (1.0, 23.0, 0.17), 'GPSAltitude': 27.0630409929773, 'name': 'IMG_2871.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.95), 'GPSLongitude': (1.0, 23.0, 1.79), 'GPSAltitude': 16.95865613254583, 'name': 'IMG_2919.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 54.53), 'GPSLongitude': (1.0, 23.0, 1.93), 'GPSAltitude': 13.816379630776856, 'name': 'IMG_2935.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 54.06), 'GPSLongitude': (1.0, 23.0, 1.22), 'GPSAltitude': 20.567450895747896, 'name': 'IMG_2923.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.09), 'GPSLongitude': (1.0, 23.0, 1.55), 'GPSAltitude': 26.416222391469915, 'name': 'IMG_2889.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.4), 'GPSLongitude': (1.0, 23.0, 1.44), 'GPSAltitude': 23.603596034279953, 'name': 'IMG_2903.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.84), 'GPSLongitude': (1.0, 23.0, 1.36), 'GPSAltitude': 21.15018644721615, 'name': 'IMG_2915.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 54.9), 'GPSLongitude': (1.0, 23.0, 1.24), 'GPSAltitude': 14.168566460587327, 'name': 'IMG_2939.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 52.8), 'GPSLongitude': (1.0, 23.0, 1.92), 'GPSAltitude': 24.78132592849705, 'name': 'IMG_2893.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 52.8), 'GPSLongitude': (1.0, 23.0, 1.58), 'GPSAltitude': 25.900921015908455, 'name': 'IMG_2885.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 52.98), 'GPSLongitude': (1.0, 23.0, 0.02), 'GPSAltitude': 25.018138372977084, 'name': 'IMG_2861.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.31), 'GPSLongitude': (1.0, 23.0, 0.79), 'GPSAltitude': 27.098378233480766, 'name': 'IMG_2877.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.01), 'GPSLongitude': (1.0, 23.0, 1.0), 'GPSAltitude': 25.218247148882988, 'name': 'IMG_2857.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.54), 'GPSLongitude': (1.0, 23.0, 0.88), 'GPSAltitude': 28.294183903338112, 'name': 'IMG_2905.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.79), 'GPSLongitude': (1.0, 23.0, 1.54), 'GPSAltitude': 19.46767166260021, 'name': 'IMG_2913.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.01), 'GPSLongitude': (1.0, 23.0, 2.2), 'GPSAltitude': 24.941195958257413, 'name': 'IMG_2895.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.01), 'GPSLongitude': (1.0, 23.0, 1.3), 'GPSAltitude': 25.83358764066374, 'name': 'IMG_2883.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 54.37), 'GPSLongitude': (1.0, 23.0, 1.14), 'GPSAltitude': 18.592958700067705, 'name': 'IMG_2929.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.68), 'GPSLongitude': (1.0, 23.0, 0.93), 'GPSAltitude': 28.69447696073215, 'name': 'IMG_2909.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 52.59), 'GPSLongitude': (1.0, 23.0, 2.0), 'GPSAltitude': 23.604383911470524, 'name': 'IMG_2948.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.16), 'GPSLongitude': (1.0, 23.0, 1.97), 'GPSAltitude': 24.525421701160425, 'name': 'IMG_2899.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 54.42), 'GPSLongitude': (1.0, 23.0, 1.68), 'GPSAltitude': 16.444231558779254, 'name': 'IMG_2933.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.91), 'GPSLongitude': (1.0, 23.0, 0.7), 'GPSAltitude': 24.25330134904047, 'name': 'IMG_2925.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 52.83), 'GPSLongitude': (1.0, 23.0, 0.56), 'GPSAltitude': 26.141605283210566, 'name': 'IMG_2859.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 52.99), 'GPSLongitude': (1.0, 22.0, 59.72), 'GPSAltitude': 23.050051828816823, 'name': 'IMG_2863.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 52.69), 'GPSLongitude': (1.0, 23.0, 1.01), 'GPSAltitude': 26.041072925398154, 'name': 'IMG_2855.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.16), 'GPSLongitude': (1.0, 23.0, 1.25), 'GPSAltitude': 26.00811176205498, 'name': 'IMG_2879.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 52.88), 'GPSLongitude': (1.0, 23.0, 0.99), 'GPSAltitude': 26.00925474914759, 'name': 'IMG_2881.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.14), 'GPSLongitude': (1.0, 23.0, 2.3), 'GPSAltitude': 25.879452835565687, 'name': 'IMG_2897.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.65), 'GPSLongitude': (1.0, 23.0, 1.37), 'GPSAltitude': 24.05250375852897, 'name': 'IMG_2911.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 52.54), 'GPSLongitude': (1.0, 23.0, 1.69), 'GPSAltitude': 25.640145705521473, 'name': 'IMG_2946.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.58), 'GPSLongitude': (1.0, 23.0, 0.89), 'GPSAltitude': 25.15395225464191, 'name': 'IMG_2907.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 54.08), 'GPSLongitude': (1.0, 23.0, 0.75), 'GPSAltitude': 22.55655233069481, 'name': 'IMG_2927.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 54.31), 'GPSLongitude': (1.0, 23.0, 1.35), 'GPSAltitude': 17.576893294099428, 'name': 'IMG_2931.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 54.6), 'GPSLongitude': (1.0, 23.0, 1.05), 'GPSAltitude': 16.216203025866275, 'name': 'IMG_2941.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 52.66), 'GPSLongitude': (1.0, 23.0, 1.16), 'GPSAltitude': 27.028786536758194, 'name': 'IMG_2853.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.5), 'GPSLongitude': (1.0, 23.0, 0.05), 'GPSAltitude': 24.898875114784207, 'name': 'IMG_2869.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 52.48), 'GPSLongitude': (1.0, 23.0, 1.7), 'GPSAltitude': 24.97281381882422, 'name': 'IMG_2849.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.46), 'GPSLongitude': (1.0, 23.0, 0.41), 'GPSAltitude': 25.81155967903711, 'name': 'IMG_2873.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.17), 'GPSLongitude': (1.0, 23.0, 0.21), 'GPSAltitude': 26.19058338022885, 'name': 'IMG_2865.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 54.0), 'GPSLongitude': (1.0, 23.0, 1.61), 'GPSAltitude': 17.652803687040493, 'name': 'IMG_2921.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 54.6), 'GPSLongitude': (1.0, 23.0, 1.72), 'GPSAltitude': 15.417461430575035, 'name': 'IMG_2937.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 52.92), 'GPSLongitude': (1.0, 23.0, 1.62), 'GPSAltitude': 24.623440214815986, 'name': 'IMG_2887.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 52.99), 'GPSLongitude': (1.0, 23.0, 1.83), 'GPSAltitude': 27.277968953123803, 'name': 'IMG_2891.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.94), 'GPSLongitude': (1.0, 23.0, 1.45), 'GPSAltitude': 19.672158548233046, 'name': 'IMG_2917.HEIC'}
# {'GPSLatitude': (43.0, 48.0, 53.32), 'GPSLongitude': (1.0, 23.0, 1.73), 'GPSAltitude': 25.14664382181012, 'name': 'IMG_2901.HEIC'}

# %%
trees_data_list
# Out:
# [{'GPSLatitude': (43.0, 48.0, 52.65),
#   'GPSLongitude': (1.0, 23.0, 1.42),
#   'GPSAltitude': 26.483714483714483,
#   'name': 'IMG_2851.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.75),
#   'GPSLongitude': (1.0, 23.0, 0.53),
#   'GPSAltitude': 28.867976171308968,
#   'name': 'IMG_2943.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 52.64),
#   'GPSLongitude': (1.0, 23.0, 1.04),
#   'GPSAltitude': 15.515895883186014,
#   'name': 'IMG_2847.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.28),
#   'GPSLongitude': (1.0, 23.0, 0.24),
#   'GPSAltitude': 24.90541162042005,
#   'name': 'IMG_2867.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.56),
#   'GPSLongitude': (1.0, 23.0, 0.17),
#   'GPSAltitude': 27.0630409929773,
#   'name': 'IMG_2871.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.56),
#   'GPSLongitude': (1.0, 23.0, 0.17),
#   'GPSAltitude': 27.0630409929773,
#   'name': 'IMG_2871.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.95),
#   'GPSLongitude': (1.0, 23.0, 1.79),
#   'GPSAltitude': 16.95865613254583,
#   'name': 'IMG_2919.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 54.53),
#   'GPSLongitude': (1.0, 23.0, 1.93),
#   'GPSAltitude': 13.816379630776856,
#   'name': 'IMG_2935.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 54.06),
#   'GPSLongitude': (1.0, 23.0, 1.22),
#   'GPSAltitude': 20.567450895747896,
#   'name': 'IMG_2923.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.09),
#   'GPSLongitude': (1.0, 23.0, 1.55),
#   'GPSAltitude': 26.416222391469915,
#   'name': 'IMG_2889.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.4),
#   'GPSLongitude': (1.0, 23.0, 1.44),
#   'GPSAltitude': 23.603596034279953,
#   'name': 'IMG_2903.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.84),
#   'GPSLongitude': (1.0, 23.0, 1.36),
#   'GPSAltitude': 21.15018644721615,
#   'name': 'IMG_2915.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 54.9),
#   'GPSLongitude': (1.0, 23.0, 1.24),
#   'GPSAltitude': 14.168566460587327,
#   'name': 'IMG_2939.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 52.8),
#   'GPSLongitude': (1.0, 23.0, 1.92),
#   'GPSAltitude': 24.78132592849705,
#   'name': 'IMG_2893.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 52.8),
#   'GPSLongitude': (1.0, 23.0, 1.58),
#   'GPSAltitude': 25.900921015908455,
#   'name': 'IMG_2885.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 52.98),
#   'GPSLongitude': (1.0, 23.0, 0.02),
#   'GPSAltitude': 25.018138372977084,
#   'name': 'IMG_2861.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.31),
#   'GPSLongitude': (1.0, 23.0, 0.79),
#   'GPSAltitude': 27.098378233480766,
#   'name': 'IMG_2877.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.01),
#   'GPSLongitude': (1.0, 23.0, 1.0),
#   'GPSAltitude': 25.218247148882988,
#   'name': 'IMG_2857.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.54),
#   'GPSLongitude': (1.0, 23.0, 0.88),
#   'GPSAltitude': 28.294183903338112,
#   'name': 'IMG_2905.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.79),
#   'GPSLongitude': (1.0, 23.0, 1.54),
#   'GPSAltitude': 19.46767166260021,
#   'name': 'IMG_2913.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.01),
#   'GPSLongitude': (1.0, 23.0, 2.2),
#   'GPSAltitude': 24.941195958257413,
#   'name': 'IMG_2895.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.01),
#   'GPSLongitude': (1.0, 23.0, 1.3),
#   'GPSAltitude': 25.83358764066374,
#   'name': 'IMG_2883.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 54.37),
#   'GPSLongitude': (1.0, 23.0, 1.14),
#   'GPSAltitude': 18.592958700067705,
#   'name': 'IMG_2929.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.68),
#   'GPSLongitude': (1.0, 23.0, 0.93),
#   'GPSAltitude': 28.69447696073215,
#   'name': 'IMG_2909.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 52.59),
#   'GPSLongitude': (1.0, 23.0, 2.0),
#   'GPSAltitude': 23.604383911470524,
#   'name': 'IMG_2948.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.16),
#   'GPSLongitude': (1.0, 23.0, 1.97),
#   'GPSAltitude': 24.525421701160425,
#   'name': 'IMG_2899.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 54.42),
#   'GPSLongitude': (1.0, 23.0, 1.68),
#   'GPSAltitude': 16.444231558779254,
#   'name': 'IMG_2933.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.91),
#   'GPSLongitude': (1.0, 23.0, 0.7),
#   'GPSAltitude': 24.25330134904047,
#   'name': 'IMG_2925.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 52.83),
#   'GPSLongitude': (1.0, 23.0, 0.56),
#   'GPSAltitude': 26.141605283210566,
#   'name': 'IMG_2859.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 52.99),
#   'GPSLongitude': (1.0, 22.0, 59.72),
#   'GPSAltitude': 23.050051828816823,
#   'name': 'IMG_2863.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 52.69),
#   'GPSLongitude': (1.0, 23.0, 1.01),
#   'GPSAltitude': 26.041072925398154,
#   'name': 'IMG_2855.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.16),
#   'GPSLongitude': (1.0, 23.0, 1.25),
#   'GPSAltitude': 26.00811176205498,
#   'name': 'IMG_2879.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 52.88),
#   'GPSLongitude': (1.0, 23.0, 0.99),
#   'GPSAltitude': 26.00925474914759,
#   'name': 'IMG_2881.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.14),
#   'GPSLongitude': (1.0, 23.0, 2.3),
#   'GPSAltitude': 25.879452835565687,
#   'name': 'IMG_2897.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.65),
#   'GPSLongitude': (1.0, 23.0, 1.37),
#   'GPSAltitude': 24.05250375852897,
#   'name': 'IMG_2911.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 52.54),
#   'GPSLongitude': (1.0, 23.0, 1.69),
#   'GPSAltitude': 25.640145705521473,
#   'name': 'IMG_2946.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.58),
#   'GPSLongitude': (1.0, 23.0, 0.89),
#   'GPSAltitude': 25.15395225464191,
#   'name': 'IMG_2907.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 54.08),
#   'GPSLongitude': (1.0, 23.0, 0.75),
#   'GPSAltitude': 22.55655233069481,
#   'name': 'IMG_2927.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 54.31),
#   'GPSLongitude': (1.0, 23.0, 1.35),
#   'GPSAltitude': 17.576893294099428,
#   'name': 'IMG_2931.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 54.6),
#   'GPSLongitude': (1.0, 23.0, 1.05),
#   'GPSAltitude': 16.216203025866275,
#   'name': 'IMG_2941.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 52.66),
#   'GPSLongitude': (1.0, 23.0, 1.16),
#   'GPSAltitude': 27.028786536758194,
#   'name': 'IMG_2853.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.5),
#   'GPSLongitude': (1.0, 23.0, 0.05),
#   'GPSAltitude': 24.898875114784207,
#   'name': 'IMG_2869.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 52.48),
#   'GPSLongitude': (1.0, 23.0, 1.7),
#   'GPSAltitude': 24.97281381882422,
#   'name': 'IMG_2849.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.46),
#   'GPSLongitude': (1.0, 23.0, 0.41),
#   'GPSAltitude': 25.81155967903711,
#   'name': 'IMG_2873.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.17),
#   'GPSLongitude': (1.0, 23.0, 0.21),
#   'GPSAltitude': 26.19058338022885,
#   'name': 'IMG_2865.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 54.0),
#   'GPSLongitude': (1.0, 23.0, 1.61),
#   'GPSAltitude': 17.652803687040493,
#   'name': 'IMG_2921.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 54.6),
#   'GPSLongitude': (1.0, 23.0, 1.72),
#   'GPSAltitude': 15.417461430575035,
#   'name': 'IMG_2937.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 52.92),
#   'GPSLongitude': (1.0, 23.0, 1.62),
#   'GPSAltitude': 24.623440214815986,
#   'name': 'IMG_2887.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 52.99),
#   'GPSLongitude': (1.0, 23.0, 1.83),
#   'GPSAltitude': 27.277968953123803,
#   'name': 'IMG_2891.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.94),
#   'GPSLongitude': (1.0, 23.0, 1.45),
#   'GPSAltitude': 19.672158548233046,
#   'name': 'IMG_2917.HEIC'},
#  {'GPSLatitude': (43.0, 48.0, 53.32),
#   'GPSLongitude': (1.0, 23.0, 1.73),
#   'GPSAltitude': 25.14664382181012,
#   'name': 'IMG_2901.HEIC'}]

# %%
features = []

for dms_data in trees_data_list:
    latitude_decimal = dms_to_decimal(*dms_data['GPSLatitude'])
    longitude_decimal = dms_to_decimal(*dms_data['GPSLongitude'])
    altitude = dms_data['GPSAltitude']
    feature_name = dms_data['name']
    
    feature = {
        "type": "Feature",
        "geometry": {
            "type": "Point",
            "coordinates": [-longitude_decimal, latitude_decimal, altitude]
        },
        "properties": {
            "name": feature_name
        }
    }
    
    features.append(feature)

geojson_data = {
    "type": "FeatureCollection",
    "features": features
}

geojson_string = json.dumps(geojson_data, indent=2)
print(geojson_string)
# Out:
# {
#   "type": "FeatureCollection",
#   "features": [
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3837277777777777,
#           43.814625,
#           26.483714483714483
#         ]
#       },
#       "properties": {
#         "name": "IMG_2851.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3834805555555556,
#           43.814930555555556,
#           28.867976171308968
#         ]
#       },
#       "properties": {
#         "name": "IMG_2943.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.383622222222222,
#           43.81462222222222,
#           15.515895883186014
#         ]
#       },
#       "properties": {
#         "name": "IMG_2847.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3834,
#           43.8148,
#           24.90541162042005
#         ]
#       },
#       "properties": {
#         "name": "IMG_2867.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3833805555555556,
#           43.814877777777774,
#           27.0630409929773
#         ]
#       },
#       "properties": {
#         "name": "IMG_2871.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3833805555555556,
#           43.814877777777774,
#           27.0630409929773
#         ]
#       },
#       "properties": {
#         "name": "IMG_2871.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3838305555555555,
#           43.81498611111111,
#           16.95865613254583
#         ]
#       },
#       "properties": {
#         "name": "IMG_2919.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3838694444444444,
#           43.81514722222222,
#           13.816379630776856
#         ]
#       },
#       "properties": {
#         "name": "IMG_2935.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3836722222222222,
#           43.815016666666665,
#           20.567450895747896
#         ]
#       },
#       "properties": {
#         "name": "IMG_2923.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3837638888888888,
#           43.814747222222216,
#           26.416222391469915
#         ]
#       },
#       "properties": {
#         "name": "IMG_2889.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3837333333333333,
#           43.81483333333333,
#           23.603596034279953
#         ]
#       },
#       "properties": {
#         "name": "IMG_2903.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3837111111111111,
#           43.81495555555555,
#           21.15018644721615
#         ]
#       },
#       "properties": {
#         "name": "IMG_2915.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3836777777777778,
#           43.81525,
#           14.168566460587327
#         ]
#       },
#       "properties": {
#         "name": "IMG_2939.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3838666666666666,
#           43.81466666666666,
#           24.78132592849705
#         ]
#       },
#       "properties": {
#         "name": "IMG_2893.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3837722222222222,
#           43.81466666666666,
#           25.900921015908455
#         ]
#       },
#       "properties": {
#         "name": "IMG_2885.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.383338888888889,
#           43.81471666666666,
#           25.018138372977084
#         ]
#       },
#       "properties": {
#         "name": "IMG_2861.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3835527777777779,
#           43.81480833333333,
#           27.098378233480766
#         ]
#       },
#       "properties": {
#         "name": "IMG_2877.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3836111111111111,
#           43.814724999999996,
#           25.218247148882988
#         ]
#       },
#       "properties": {
#         "name": "IMG_2857.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3835777777777778,
#           43.81487222222222,
#           28.294183903338112
#         ]
#       },
#       "properties": {
#         "name": "IMG_2905.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.383761111111111,
#           43.81494166666666,
#           19.46767166260021
#         ]
#       },
#       "properties": {
#         "name": "IMG_2913.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3839444444444444,
#           43.814724999999996,
#           24.941195958257413
#         ]
#       },
#       "properties": {
#         "name": "IMG_2895.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3836944444444443,
#           43.814724999999996,
#           25.83358764066374
#         ]
#       },
#       "properties": {
#         "name": "IMG_2883.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.38365,
#           43.815102777777774,
#           18.592958700067705
#         ]
#       },
#       "properties": {
#         "name": "IMG_2929.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3835916666666666,
#           43.81491111111111,
#           28.69447696073215
#         ]
#       },
#       "properties": {
#         "name": "IMG_2909.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.383888888888889,
#           43.81460833333333,
#           23.604383911470524
#         ]
#       },
#       "properties": {
#         "name": "IMG_2948.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3838805555555556,
#           43.814766666666664,
#           24.525421701160425
#         ]
#       },
#       "properties": {
#         "name": "IMG_2899.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3838,
#           43.81511666666666,
#           16.444231558779254
#         ]
#       },
#       "properties": {
#         "name": "IMG_2933.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3835277777777777,
#           43.814975,
#           24.25330134904047
#         ]
#       },
#       "properties": {
#         "name": "IMG_2925.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3834888888888888,
#           43.814674999999994,
#           26.141605283210566
#         ]
#       },
#       "properties": {
#         "name": "IMG_2859.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3832555555555557,
#           43.81471944444444,
#           23.050051828816823
#         ]
#       },
#       "properties": {
#         "name": "IMG_2863.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.383613888888889,
#           43.814636111111106,
#           26.041072925398154
#         ]
#       },
#       "properties": {
#         "name": "IMG_2855.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3836805555555556,
#           43.814766666666664,
#           26.00811176205498
#         ]
#       },
#       "properties": {
#         "name": "IMG_2879.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3836083333333333,
#           43.81468888888889,
#           26.00925474914759
#         ]
#       },
#       "properties": {
#         "name": "IMG_2881.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3839722222222222,
#           43.81476111111111,
#           25.879452835565687
#         ]
#       },
#       "properties": {
#         "name": "IMG_2897.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.383713888888889,
#           43.814902777777775,
#           24.05250375852897
#         ]
#       },
#       "properties": {
#         "name": "IMG_2911.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3838027777777777,
#           43.81459444444444,
#           25.640145705521473
#         ]
#       },
#       "properties": {
#         "name": "IMG_2946.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3835805555555556,
#           43.81488333333333,
#           25.15395225464191
#         ]
#       },
#       "properties": {
#         "name": "IMG_2907.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3835416666666667,
#           43.81502222222222,
#           22.55655233069481
#         ]
#       },
#       "properties": {
#         "name": "IMG_2927.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3837083333333333,
#           43.81508611111111,
#           17.576893294099428
#         ]
#       },
#       "properties": {
#         "name": "IMG_2931.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3836249999999999,
#           43.81516666666666,
#           16.216203025866275
#         ]
#       },
#       "properties": {
#         "name": "IMG_2941.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3836555555555554,
#           43.81462777777777,
#           27.028786536758194
#         ]
#       },
#       "properties": {
#         "name": "IMG_2853.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3833472222222223,
#           43.81486111111111,
#           24.898875114784207
#         ]
#       },
#       "properties": {
#         "name": "IMG_2869.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3838055555555555,
#           43.81457777777778,
#           24.97281381882422
#         ]
#       },
#       "properties": {
#         "name": "IMG_2849.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3834472222222223,
#           43.81485,
#           25.81155967903711
#         ]
#       },
#       "properties": {
#         "name": "IMG_2873.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3833916666666666,
#           43.814769444444444,
#           26.19058338022885
#         ]
#       },
#       "properties": {
#         "name": "IMG_2865.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3837805555555556,
#           43.815,
#           17.652803687040493
#         ]
#       },
#       "properties": {
#         "name": "IMG_2921.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.383811111111111,
#           43.81516666666666,
#           15.417461430575035
#         ]
#       },
#       "properties": {
#         "name": "IMG_2937.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3837833333333334,
#           43.814699999999995,
#           24.623440214815986
#         ]
#       },
#       "properties": {
#         "name": "IMG_2887.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.3838416666666666,
#           43.81471944444444,
#           27.277968953123803
#         ]
#       },
#       "properties": {
#         "name": "IMG_2891.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.383736111111111,
#           43.81498333333333,
#           19.672158548233046
#         ]
#       },
#       "properties": {
#         "name": "IMG_2917.HEIC"
#       }
#     },
#     {
#       "type": "Feature",
#       "geometry": {
#         "type": "Point",
#         "coordinates": [
#           -1.383813888888889,
#           43.814811111111105,
#           25.14664382181012
#         ]
#       },
#       "properties": {
#         "name": "IMG_2901.HEIC"
#       }
#     }
#   ]
# }

# %%
output_filename = directory_path + "/" +"output.geojson"

with open(output_filename, "w") as f:
    json.dump(geojson_data, f, indent=2)

print(f"GeoJSON data written to {output_filename}")
# Out:
# GeoJSON data written to /Users/WDescamps/Downloads/images_dune/output.geojson
